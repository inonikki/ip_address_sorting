# %%
# %matplotlib
import pandas as pd
import numpy as np
import vincent
import json
vincent.core.initialize_notebook()
# Out:
# Using matplotlib backend: Qt5Agg
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-134135cfbea7> in <module>()
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import vincent
#       5 import json
#       6 vincent.core.initialize_notebook()
#
# ModuleNotFoundError: No module named 'vincent'

# %%
all_one = pd.read_csv('modified_table.csv', encoding="ISO-8859-1")
del all_one['Unnamed: 0']
all_one = all_one.groupby(['country', 'code_country'])['last_ip'].count()
all_one.columns = ['country', 'code_country', 'ip']
all_one.to_csv('all_ip.csv')
all_two = pd.read_csv('all_ip.csv')
all_two.columns = ['country', 'code_country', 'ip']
all_two.to_csv('all_two.csv')
print(all_two)

# %%
import numpy as np
import pandas as pd 
pd.options.mode.chained_assignment = None

import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-74a53f1ea346> in <module>()
#       3 pd.options.mode.chained_assignment = None
#       4
# ----> 5 import plotly.plotly as py
#       6 import plotly.graph_objs as go
#       7 from plotly import tools
#
# ModuleNotFoundError: No module named 'plotly'

# %%
code_co = np.asarray(all_two.code_country)
code_country = ['AF', 'AL', 'DZ', 'AS', 'AD', 'AO', 'AG', 'AR', 'AM', 'AU', 'AT', 'AZ', 'BS', 'BH', 'BD',
 'BB', 'BY', 'BE', 'BZ', 'BJ', 'BM', 'BO', 'BA', 'BW', 'BR', 'VG', 'BN', 'BG', 'BF', 'KH',
 'CM', 'CA', 'CV', 'KY', 'CL', 'CN', 'CO', 'CD', 'CK', 'CR', 'HR', 'CU', 'CY', 'CZ', 'DK',
 'DJ', 'DM', 'DO', 'EC', 'EG', 'SV', 'GQ', 'EE', 'ET', 'FO', 'FJ', 'FI', 'FR', 'GF', 'PF',
 'GA', 'GM', 'GE', 'DE', 'GH', 'GI', 'GR', 'GL', 'GP', 'GU', 'GT', 'GN', 'GW', 'GY', 'HT',
 'JO', 'HN', 'HK', 'HU', 'IS', 'IN', 'ID', 'IR', 'IQ', 'IE', 'IM', 'IL', 'IT', 'CI', 'JM',
 'JP', 'JE', 'KZ', 'KE', 'XK', 'KW', 'KG', 'LA', 'LV', 'LB', 'LR', 'LY', 'LI', 'LU', 'MO',
 'MK', 'MG', 'MY', 'MV', 'ML', 'MT', 'MU', 'MX', 'MC', 'MN', 'ME', 'MA', 'MZ', 'MM', 'NP',
 'NL', 'NC', 'NZ', 'NI', 'NE', 'NG', 'KP', 'MP', 'NO', 'OM', 'PK', 'PS', 'PA', 'PG', 'PY',
 'PE', 'PH', 'PL', 'PT', 'PR', 'QA', 'RE', 'KR', 'LT', 'MD', 'CG', 'RO', 'RU', 'RW', 'WS',
 'SM', 'SA', 'SN', 'RS', 'SC', 'SL', 'SG', 'SK', 'SI', 'SO', 'ZA', 'SS', 'ES', 'LK', 'SD',
 'SR', 'SJ', 'SE', 'CH', 'SY', 'TW', 'TJ', 'TZ', 'TH', 'TG', 'TO', 'TT', 'TN', 'TR', 'TM',
 'UG', 'UA', 'AE', 'GB', 'US', 'UY', 'UZ', 'VU', 'VA', 'VE', 'VN', 'YE', 'ZM', 'ZW']
print(code_co)
print(code_country)
# Out:
# ['AF' 'AL' 'DZ' 'AS' 'AD' 'AO' 'AG' 'AR' 'AM' 'AU' 'AT' 'AZ' 'BS' 'BH' 'BD'
#  'BB' 'BY' 'BE' 'BZ' 'BJ' 'BM' 'BO' 'BA' 'BW' 'BR' 'VG' 'BN' 'BG' 'BF' 'KH'
#  'CM' 'CA' 'CV' 'KY' 'CL' 'CN' 'CO' 'CD' 'CK' 'CR' 'HR' 'CU' 'CY' 'CZ' 'DK'
#  'DJ' 'DM' 'DO' 'EC' 'EG' 'SV' 'GQ' 'EE' 'ET' 'FO' 'FJ' 'FI' 'FR' 'GF' 'PF'
#  'GA' 'GM' 'GE' 'DE' 'GH' 'GI' 'GR' 'GL' 'GP' 'GU' 'GT' 'GN' 'GW' 'GY' 'HT'
#  'JO' 'HN' 'HK' 'HU' 'IS' 'IN' 'ID' 'IR' 'IQ' 'IE' 'IM' 'IL' 'IT' 'CI' 'JM'
#  'JP' 'JE' 'KZ' 'KE' 'XK' 'KW' 'KG' 'LA' 'LV' 'LB' 'LR' 'LY' 'LI' 'LU' 'MO'
#  'MK' 'MG' 'MY' 'MV' 'ML' 'MT' 'MU' 'MX' 'MC' 'MN' 'ME' 'MA' 'MZ' 'MM' 'NP'
#  'NL' 'NC' 'NZ' 'NI' 'NE' 'NG' 'KP' 'MP' 'NO' 'OM' 'PK' 'PS' 'PA' 'PG' 'PY'
#  'PE' 'PH' 'PL' 'PT' 'PR' 'QA' 'RE' 'KR' 'LT' 'MD' 'CG' 'RO' 'RU' 'RW' 'WS'
#  'SM' 'SA' 'SN' 'RS' 'SC' 'SL' 'SG' 'SK' 'SI' 'SO' 'ZA' 'SS' 'ES' 'LK' 'SD'
#  'SR' 'SJ' 'SE' 'CH' 'SY' 'TW' 'TJ' 'TZ' 'TH' 'TG' 'TO' 'TT' 'TN' 'TR' 'TM'
# ...

# %%
all_i = np.asarray(all_two.ip)
all_ip = [     32,      85,     268,       1,      12,      13,      10,     197,    5250,\
     552,     525,    3758,       3,      11,     146,       4,   19380,     647,\
      13,      26,       2,      34,      43,      11,     869,       4,       3,\
    1448,       8,     122,      18,    1253,       6,       1,      93,    4735,\
     180,       1,       1,      33,     294,       8,     640,    3446,     337,\
       2,       1,     116,      78,     517,       3,       2,    1655,       4,\
       4,       3,     811,    2969,       1,       2,       9,       1,    2565,\
    7263,      84,     393,     612,       1,       1,       2,      20,       2,\
       1,       4,      10,      62,      10,     351,     656,     111,    1141,\
     952,     309,     132,     243,      10,    2367,    2099,      29,      10,\
     558,      15,   15982,      38,       2,      29,    2477,      10,    2903,\
      46,       6,      12,       5,     405,       5,      48,       8,     274,\
      20,       1,      72,      17,     348,      12,      71,     429,     336,\
       6,      27,      40,    5186,       2,     149,      14,       2,     353,\
       5,       1,     744,       9,     387,      84,      43,       1,       5,\
      86,     264,    1706,     388,       5,      29,       2,     625,    1333,\
    7728,       4,    1390, 1058559,       6,       1,       1,     188,      25,\
     378,      19,       2,     361,     194,     142,       1,     152,       2,\
    2220,      97,      15,       1,       1,    2279,     768,      44,     133,\
    1061,      19,    2217,      57,       1,       6,     122,    2641,     842,\
      11,   77887,     533,    6020,   10428,      20,    4906,       2,       1,\
     624,     981,      23,      5,       5]
print(all_i)
print(all_ip)
# Out:
# [     32      85     268       1      12      13      10     197    5250
#      552     525    3758       3      11     146       4   19380     647
#       13      26       2      34      43      11     869       4       3
#     1448       8     122      18    1253       6       1      93    4735
#      180       1       1      33     294       8     640    3446     337
#        2       1     116      78     517       3       2    1655       4
#        4       3     811    2969       1       2       9       1    2565
#     7263      84     393     612       1       1       2      20       2
#        1       4      10      62      10     351     656     111    1141
#      952     309     132     243      10    2367    2099      29      10
#      558      15   15982      38       2      29    2477      10    2903
#       46       6      12       5     405       5      48       8     274
#       20       1      72      17     348      12      71     429     336
# ...

# %%
import plotly.plotly as py
import plotly 
import pandas as pd
plotly.tools.set_credentials_file(username='inonikki', api_key='xbby1kqh0q')

df = pd.read_csv('all_two.csv')

data = [ dict(
        type = 'choropleth',
        locations = df['code_country'],
        z = df['ip'],
        text = df['country'],
        #colorscale = [[0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
        #    [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
        autocolorscale = True,
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            #autotick = False,
            tickprefix = '$',
            title = '2222'),
      ) ]

layout = dict(
    title = 'Number of IP addresses in each country',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
iplot( fig)
# Out:
# <div id="7138d638-a6b2-483b-ab3b-fc777422641f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7138d638-a6b2-483b-ab3b-fc777422641f", [{"type": "choropleth", "locations": ["AF", "AL", "DZ", "AS", "AD", "AO", "AG", "AR", "AM", "AU", "AT", "AZ", "BS", "BH", "BD", "BB", "BY", "BE", "BZ", "BJ", "BM", "BO", "BA", "BW", "BR", "VG", "BN", "BG", "BF", "KH", "CM", "CA", "CV", "KY", "CL", "CN", "CO", "CD", "CK", "CR", "HR", "CU", "CY", "CZ", "DK", "DJ", "DM", "DO", "EC", "EG", "SV", "GQ", "EE", "ET", "FO", "FJ", "FI", "FR", "GF", "PF", "GA", "GM", "GE", "DE", "GH", "GI", "GR", "GL", "GP", "GU", "GT", "GN", "GW", "GY", "HT", "JO", "HN", "HK", "HU", "IS", "IN", "ID", "IR", "IQ", "IE", "IM", "IL", "IT", "CI", "JM", "JP", "JE", "KZ", "KE", "XK", "KW", "KG", "LA", "LV", "LB", "LR", "LY", "LI", "LU", "MO", "MK", "
# ...

# %%
import plotly.plotly as py
import pandas as pd
import plotly

plotly.tools.set_credentials_file(username='inonikki', api_key='xbby1kqh0q')

df = pd.read_csv('all_two.csv')

data = [ dict(
        type = 'choropleth',
        locations = df['code_country'],
        z = df['ip'],
        text = df['country'],
        #colorscale = [[0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
           #[0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
        autocolorscale = True,
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            )
        ),
        tick0 = 'locations',
        zmin = 0,
        dtick = 1000,
        colorbar = dict(
            #autotick = False,
            tickprefix = '$',
            title = '1234'
        ),
    ) ]

layout = dict(
    title = '1234',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
iplot( fig)
# Out:
# ---------------------------------------------------------------------------
# PlotlyDictKeyError                        Traceback (most recent call last)
# c:\program files\python36\lib\site-packages\plotly\tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#    1384         try:
# -> 1385             graph_objs.Figure(figure)
#    1386         except exceptions.PlotlyError as err:
#
# c:\program files\python36\lib\site-packages\plotly\graph_objs\graph_objs.py in __init__(self, *args, **kwargs)
#    1162     def __init__(self, *args, **kwargs):
# -> 1163         super(Figure, self).__init__(*args, **kwargs)
#    1164         if 'data' not in self:
#
# c:\program files\python36\lib\site-packages\plotly\graph_objs\graph_objs.py in __init__(self, *args, **kwargs)
#     376         for key, val in d.items():
# --> 377             self.__setitem__(key, val, _raise=_raise)
#     378
#
# ...
